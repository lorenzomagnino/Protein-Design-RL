# %%
import pandas as pd
import matplotlib.pyplot as plt



""" ---- Train_loss ---- """
# Load the CSV files
csv_file_A2C = "/gpfsnyu/home/lm5489/Protein-Design-RL/utility/results_csv/problem_1.py/A2C_Protein_Design_A2C_1.csv"
data_A2C = pd.read_csv(csv_file_A2C)

csv_file_DQN = "/gpfsnyu/home/lm5489/Protein-Design-RL/utility/results_csv/problem_1.py/train_loss_DQN.csv"
data_DQN = pd.read_csv(csv_file_DQN)

csv_file_PPO = "/gpfsnyu/home/lm5489/Protein-Design-RL/utility/results_csv/problem_1.py/train_loss_PPO.csv"
data_PPO = pd.read_csv(csv_file_PPO)

data_DQN
# Out:
#         Wall time   Step     Value
# 0    1.736353e+09    120  0.675704
# 1    1.736353e+09    180  0.509494
# 2    1.736353e+09    240  0.391308
# 3    1.736353e+09    300  0.322981
# 4    1.736353e+09    360  0.214544
# ..            ...    ...       ...
# 834  1.736353e+09  49800  0.049806
# 835  1.736353e+09  49860  0.035472
# 836  1.736353e+09  49920  0.070305
# 837  1.736353e+09  49980  0.023708
# 838  1.736353e+09  50000  0.039272
#
# [839 rows x 3 columns]
